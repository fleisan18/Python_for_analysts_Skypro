# %% [markdown]
# # Домашнее задание 5.2

# %% [markdown]
# # ✏️ 🗒️ 📝
#
# Сегодня тебе нужно выполнить задачу от руководительницы отдела контент-маркетинга новой онлайн-школы английского языка. Она хочет составить ТЗ копирайтеру на написание постов, но для этого ей нужно знать, какие типы постов популярны. За завтраком вы с ней обсуждали твое последнее занятие с курса Python, где мы парсили страницы сообществ ВК, и у вас появилась идея – проанализировать самые успешные посты известной онлайн-школы Skyeng  в [сообществе Skyeng в ВК](https://vk.com/skyeng).
#
# Теперь перед тобой стоит задача – выгрузить маркетологам для анализа 50 самых популярных постов за все время существования сообщества. Метрику популярности будем считать как сумму лайков, репостов и комментариев к каждому посту. Если останется время, для дополнительного анализа выгрузи все комментарии к этим постам в отдельный файл.

# %% [markdown]
# ## Задание 1
#
# Получи собственный `access_token` в ВК. Важно пройти этот путь самостоятельно, можешь использовать документацию API ВК или рекомендации из ноутбука занятия.  Токен присылай вместе с файлом ноутбука в файле с именем `my_own_token.py`. Обещаем не делать ничего противозаконного.
#
# *Если тебе некомфортно, можешь не присылать токен нам. Однако получить его все же обязательно – это необходимо для полноценного освоения темы урока, а также для выполнения заданий ниже.*

# %%
# читаем токен из файла my_own_token.py, куда мы сохранили access_token
from my_own_token import my_own_token as token

# %% [markdown]
# ## Задание 2
#
# __Сформируй запрос, который получает 100 записей со стены сообщества__
#
# 1. Найди в документации метод, который отдает все записи со стены сообщества Skyeng: https://vk.com/skyeng
# 2. Создай переменую для URL
# 3. Создай переменную с параметрами
# 4. Создай переменную запроса
# 5. Создай переменную, в которой будут данные ответа в формате словаря

# %%
import requests 
import pandas as pd

# %%
url = 'https://api.vk.com/method/wall.get'

params = {'access_token': token,
          'v':'5.131', 
          'owner_id': '-' + str(51890028),
          'count': 100,
          'filter': 'all'
        }
req = requests.get(url, params)
req.content
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000019C6DA6E820>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='api.vk.com', port=443): Max retries exceeded with url: /method/wall.get?access_token=37d0de86be3c15707b8f1e9f19267916a6c52733e936b4680e9e8b49cbc3d576f76a718f64b31a35f1067&v=5.131&owner_id=-51890028&count=100&filter=all (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C6DA6E820>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11148/1055600274.py in <module>
#       7           'filter': 'all'
#       8         }
# ----> 9 req = requests.get(url, params)
#      10 req.content
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='api.vk.com', port=443): Max retries exceeded with url: /method/wall.get?access_token=37d0de86be3c15707b8f1e9f19267916a6c52733e936b4680e9e8b49cbc3d576f76a718f64b31a35f1067&v=5.131&owner_id=-51890028&count=100&filter=all (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019C6DA6E820>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
res = req.json()

print('Кол-во записей:', len(pd.DataFrame(res['response'])))
# Out:
# Кол-во записей: 100

# %% [markdown]
# ## Задание 3
#
# Выгрузи в переменную `posts` в формате датафрейма __все записи__ сообщества Skyeng: https://vk.com/skyeng,
#
# 1. Используй цикл `While`
# 2. Для выгрузки __всех записей__ тебе поможет параметр `offset`.
# 3. Записей больше 7000! Не забудь про ограничение "не больше 3 запросов в секунду" от API VK, здесь тебе поможет библиотека `time`

# %%
import time

# %%
# напиши здесь код
offset = 0
max_count = 100
posts = pd.DataFrame()

while True:      # Повторять цикл пока его не остановят по условию ниже
    
    url = 'https://api.vk.com/method/wall.get'
    params = {
        'owner_id': '-' + str(51890028),
        'access_token': token,
        'v':'5.131',
        'filter': 'all',
        'count': max_count,
        'offset': offset
    }
    
    req = requests.get(url, params)
    res = req.json()
    
    if len(res['response']['items']) != 0:      # Проверяем вернулись ли нам хоть какие-нибудь записи
        posts = pd.concat([posts, pd.DataFrame(res['response']['items'])]) 
    else:
        break                                   # Если нам ничего не вернулось, то прервать цикл
    print('Уже отображено', offset, 'постов')
    offset = offset + max_count                 # Смещаем offset на число возвращенных записей
    time.sleep(0.5)                             # Опять контролируем частоту запросов, чтобы нас не ограничили
# Out:
# Уже отображено 0 постов
# Уже отображено 100 постов
# Уже отображено 200 постов
# Уже отображено 300 постов
# Уже отображено 400 постов
# Уже отображено 500 постов
# Уже отображено 600 постов
# Уже отображено 700 постов
# Уже отображено 800 постов
# Уже отображено 900 постов
# Уже отображено 1000 постов
# Уже отображено 1100 постов
# Уже отображено 1200 постов
# Уже отображено 1300 постов
# Уже отображено 1400 постов
# Уже отображено 1500 постов
# Уже отображено 1600 постов
# Уже отображено 1700 постов
# Уже отображено 1800 постов
# Уже отображено 1900 постов
# Уже отображено 2000 постов
# Уже отображено 2100 постов
# Уже отображено 2200 постов
# Уже отображено 2300 постов
# Уже отображено 2400 постов
# Уже отображено 2500 постов
# Уже отображено 2600 постов
# Уже отображено 2700 постов
# Уже отображено 2800 постов
# Уже отображено 2900 постов
# Уже отображено 3000 постов
# Уже отображено 3100 постов
# Уже отображено 3200 постов
# Уже отображено 3300 постов
# Уже отображено 3400 постов
# Уже отображено 3500 постов
# Уже отображено 3600 постов
# Уже отображено 3700 постов
# Уже отображено 3800 постов
# Уже отображено 3900 постов
# Уже отображено 4000 постов
# Уже отображено 4100 постов
# Уже отображено 4200 постов
# Уже отображено 4300 постов
# Уже отображено 4400 постов
# Уже отображено 4500 постов
# Уже отображено 4600 постов
# Уже отображено 4700 постов
# Уже отображено 4800 постов
# Уже отображено 4900 постов
# Уже отображено 5000 постов
# Уже отображено 5100 постов
# Уже отображено 5200 постов
# Уже отображено 5300 постов
# Уже отображено 5400 постов
# Уже отображено 5500 постов
# Уже отображено 5600 постов
# Уже отображено 5700 постов
# Уже отображено 5800 постов
# Уже отображено 5900 постов
# Уже отображено 6000 постов
# Уже отображено 6100 постов
# Уже отображено 6200 постов
# Уже отображено 6300 постов
# Уже отображено 6400 постов
# Уже отображено 6500 постов
# Уже отображено 6600 постов
# Уже отображено 6700 постов
# Уже отображено 6800 постов
# Уже отображено 6900 постов
# Уже отображено 7000 постов
# Уже отображено 7100 постов
# Уже отображено 7200 постов
# Уже отображено 7300 постов
# Уже отображено 7400 постов
# Уже отображено 7500 постов
# Уже отображено 7600 постов
# Уже отображено 7700 постов
# Уже отображено 7800 постов
# Уже отображено 7900 постов
# Уже отображено 8000 постов

# %%
print('Кол-во записей:', len(posts))
# Out:
# Кол-во записей: 8013

# %%
posts.head()
# Out:
#       id   from_id  owner_id        date  marked_as_ads  is_favorite  \
# 0  86655 -51890028 -51890028  1649265078              0        False
# 1  86653 -51890028 -51890028  1649262480              0        False
# 2  86634 -51890028 -51890028  1649179740              0        False
# 3  86629 -51890028 -51890028  1649174266              0        False
# 4  86626 -51890028 -51890028  1649095861              0        False
#
#   post_type                                               text  \
# 0      post  В предыдущем посте рассказали, какие причины д...
# 1      post  А до английского ли сейчас? Как никогда раньше...
# 2      post  Мы часто говорим, что важно определить свой ур...
# 3      post  Skyeng сохраняет цены на уроки!\n\nДо 29 апрел...
# 4      post  «Никогда не знаешь, чего ждать от жизни»\n\nСе...
#
#                                          attachments     post_source  ...  \
# 0  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 1  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 2  [{'type': 'video', 'video': {'access_key': '11...  {'type': 'vk'}  ...
# 3  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 4  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
#
#              views                donut short_text_rate  \
# 0  {'count': 3122}  {'is_donut': False}             0.8
# 1  {'count': 2991}  {'is_donut': False}             0.8
# 2  {'count': 4965}  {'is_donut': False}             0.8
# 3  {'count': 3834}  {'is_donut': False}             0.8
# 4  {'count': 5186}  {'is_donut': False}             0.8
#
#                            hash carousel_offset        edited copy_history  \
# 0  P9sxowS2s6M9ozub-QaH6ZMUY43q             NaN           NaN          NaN
# 1  tkLLyHVKl3eqq2kjwv0fI29dJ3HL             0.0           NaN          NaN
# 2  y4lGnsZ-JlZXrVuDwpo1f-b-1D_m             NaN           NaN          NaN
# 3  g5yejxkvubcgBDQR_OuSN1h_2Avn             0.0  1.649178e+09          NaN
# 4  mFKXQNF7UQFRZAJGVd6oymJgDZHL             0.0  1.649097e+09          NaN
#
#    signer_id  zoom_text  geo
# 0        NaN        NaN  NaN
# 1        NaN        NaN  NaN
# 2        NaN        NaN  NaN
# 3        NaN        NaN  NaN
# 4        NaN        NaN  NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Задание 4
#
# Выгрузи 50 самых популярных постов. Метрикой популярности мы считаем сумму лайков, репостов и комментариев.
#
# 1. Создай столбцы с числовыми значениями для лайков, репостов и комментариев и забери из словаря только значение по ключу `count`
# 2. Создай отдельный столбец, где будет сумма пользовательских активностей для каждого поста
# 3. Отсортируй дата-фрейм по столбцу с суммой пользовательских активностей
# 4. Выбери 50 самых популярных постов
#
# Если задание кажется легким, реализуй тот же код с `lambda` функцией.

# %%
posts.columns
# Out:
# Index(['id', 'from_id', 'owner_id', 'date', 'marked_as_ads', 'is_favorite',
#        'post_type', 'text', 'attachments', 'post_source', 'comments', 'likes',
#        'reposts', 'views', 'donut', 'short_text_rate', 'hash',
#        'carousel_offset', 'edited', 'copy_history', 'signer_id', 'zoom_text',
#        'geo'],
#       dtype='object')

# %%
# вытащи из словарей столбцов comments, likes, reposts только нужные значения

activity = posts[['comments', 'likes', 'reposts']]
activity['comments_count'] = activity['comments'].apply(lambda x: x.get('count'))
activity['likes_count'] = activity['likes'].apply(lambda x: x.get('count'))
activity['reposts_count'] = activity['reposts'].apply(lambda x: x.get('count'))
activity
# Out:
# C:\Users\1645295\AppData\Local\Temp/ipykernel_11148/2727759401.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   activity['comments_count'] = activity['comments'].apply(lambda x: x.get('count'))
# C:\Users\1645295\AppData\Local\Temp/ipykernel_11148/2727759401.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   activity['likes_count'] = activity['likes'].apply(lambda x: x.get('count'))
# C:\Users\1645295\AppData\Local\Temp/ipykernel_11148/2727759401.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   activity['reposts_count'] = activity['reposts'].apply(lambda x: x.get('count'))
#                                              comments  \
# 0   {'can_post': 1, 'count': 2, 'groups_can_post':...
# 1   {'can_post': 1, 'count': 0, 'groups_can_post':...
# 2   {'can_post': 1, 'count': 1, 'groups_can_post':...
# 3   {'can_post': 1, 'count': 9, 'groups_can_post':...
# 4   {'can_post': 1, 'count': 0, 'groups_can_post':...
# ..                                                ...
# 8   {'can_post': 1, 'count': 0, 'groups_can_post':...
# 9   {'can_post': 1, 'count': 0, 'groups_can_post':...
# 10  {'can_post': 1, 'count': 4, 'groups_can_post':...
# 11  {'can_post': 1, 'count': 0, 'groups_can_post':...
# 12  {'can_post': 1, 'count': 0, 'groups_can_post':...
#
#                                                 likes  \
# 0   {'can_like': 1, 'count': 7, 'user_likes': 0, '...
# 1   {'can_like': 1, 'count': 13, 'user_likes': 0, ...
# 2   {'can_like': 1, 'count': 25, 'user_likes': 0, ...
# 3   {'can_like': 1, 'count': 4, 'user_likes': 0, '...
# 4   {'can_like': 1, 'count': 16, 'user_likes': 0, ...
# ..                                                ...
# 8   {'can_like': 1, 'count': 2, 'user_likes': 0, '...
# 9   {'can_like': 1, 'count': 3, 'user_likes': 0, '...
# 10  {'can_like': 1, 'count': 4, 'user_likes': 0, '...
# 11  {'can_like': 1, 'count': 7, 'user_likes': 0, '...
# 12  {'can_like': 1, 'count': 21, 'user_likes': 0, ...
#
#                               reposts  comments_count  likes_count  \
# 0    {'count': 0, 'user_reposted': 0}               2            7
# 1    {'count': 9, 'user_reposted': 0}               0           13
# 2   {'count': 15, 'user_reposted': 0}               1           25
# 3    {'count': 2, 'user_reposted': 0}               9            4
# 4    {'count': 3, 'user_reposted': 0}               0           16
# ..                                ...             ...          ...
# 8    {'count': 0, 'user_reposted': 0}               0            2
# 9    {'count': 0, 'user_reposted': 0}               0            3
# 10   {'count': 0, 'user_reposted': 0}               4            4
# 11   {'count': 0, 'user_reposted': 0}               0            7
# 12   {'count': 0, 'user_reposted': 0}               0           21
#
#     reposts_count
# 0               0
# 1               9
# 2              15
# 3               2
# 4               3
# ..            ...
# 8               0
# 9               0
# 10              0
# 11              0
# 12              0
#
# [8013 rows x 6 columns]

# %%
# заполни даными с прошлого шага новые столбцы
posts['comments_count'] = activity['comments_count']
posts['likes_count'] = activity['likes_count']
posts['reposts_count'] = activity['reposts_count']

# %%
# заполни данными столбец с суммой по всем активностям

posts['activity'] = posts['comments_count'] +posts['likes_count'] + posts['reposts_count']
posts
# Out:
#        id   from_id  owner_id        date  marked_as_ads  is_favorite  \
# 0   86655 -51890028 -51890028  1649265078              0        False
# 1   86653 -51890028 -51890028  1649262480              0        False
# 2   86634 -51890028 -51890028  1649179740              0        False
# 3   86629 -51890028 -51890028  1649174266              0        False
# 4   86626 -51890028 -51890028  1649095861              0        False
# ..    ...       ...       ...         ...            ...          ...
# 8      15 -51890028 -51890028  1386062029              0        False
# 9      13 -51890028 -51890028  1377498858              0        False
# 10      7 -51890028 -51890028  1369766429              0        False
# 11      6 -51890028 -51890028  1366634513              0        False
# 12      4 -51890028 -51890028  1365687628              0        False
#
#    post_type                                               text  \
# 0       post  В предыдущем посте рассказали, какие причины д...
# 1       post  А до английского ли сейчас? Как никогда раньше...
# 2       post  Мы часто говорим, что важно определить свой ур...
# 3       post  Skyeng сохраняет цены на уроки!\n\nДо 29 апрел...
# 4       post  «Никогда не знаешь, чего ждать от жизни»\n\nСе...
# ..       ...                                                ...
# 8       post  Приходите на онлайн встречу (goo.gl/4eKCYD) ра...
# 9       post  Мы начинаем серию интервью с преподавателями ш...
# 10      post  В прошедшее воскресенье у нас прошла первая вс...
# 11      post      Изучение английского по скайпу в школе Skyeng
# 12      post
#
#                                           attachments  \
# 0   [{'type': 'photo', 'photo': {'album_id': -7, '...
# 1   [{'type': 'photo', 'photo': {'album_id': -7, '...
# 2   [{'type': 'video', 'video': {'access_key': '11...
# 3   [{'type': 'photo', 'photo': {'album_id': -7, '...
# 4   [{'type': 'photo', 'photo': {'album_id': -7, '...
# ..                                                ...
# 8   [{'type': 'photo', 'photo': {'album_id': -7, '...
# 9   [{'type': 'video', 'video': {'access_key': '14...
# 10  [{'type': 'video', 'video': {'access_key': '02...
# 11  [{'type': 'video', 'video': {'access_key': 'a4...
# 12  [{'type': 'photo', 'photo': {'album_id': -6, '...
#
#                                 post_source  ... carousel_offset  \
# 0                            {'type': 'vk'}  ...             NaN
# 1                            {'type': 'vk'}  ...             0.0
# 2                            {'type': 'vk'}  ...             NaN
# 3                            {'type': 'vk'}  ...             0.0
# 4                            {'type': 'vk'}  ...             0.0
# ..                                      ...  ...             ...
# 8                            {'type': 'vk'}  ...             NaN
# 9                            {'type': 'vk'}  ...             NaN
# 10                           {'type': 'vk'}  ...             NaN
# 11                           {'type': 'vk'}  ...             NaN
# 12  {'data': 'profile_photo', 'type': 'vk'}  ...             NaN
#
#           edited copy_history signer_id zoom_text  geo comments_count  \
# 0            NaN          NaN       NaN       NaN  NaN              2
# 1            NaN          NaN       NaN       NaN  NaN              0
# 2            NaN          NaN       NaN       NaN  NaN              1
# 3   1.649178e+09          NaN       NaN       NaN  NaN              9
# 4   1.649097e+09          NaN       NaN       NaN  NaN              0
# ..           ...          ...       ...       ...  ...            ...
# 8   1.386062e+09          NaN       NaN       NaN  NaN              0
# 9   1.377499e+09          NaN       NaN       NaN  NaN              0
# 10           NaN          NaN       NaN       NaN  NaN              4
# 11           NaN          NaN       NaN       NaN  NaN              0
# 12           NaN          NaN       NaN       NaN  NaN              0
#
#     likes_count  reposts_count activity
# 0             7              0        9
# 1            13              9       22
# 2            25             15       41
# 3             4              2       15
# 4            16              3       19
# ..          ...            ...      ...
# 8             2              0        2
# 9             3              0        3
# 10            4              0        8
# 11            7              0        7
# 12           21              0       21
#
# [8013 rows x 27 columns]

# %%
# сортировка
posts.sort_values(by='activity', ascending = False, inplace = True)
posts
# Out:
#        id   from_id  owner_id        date  marked_as_ads  is_favorite  \
# 12  63081 -51890028 -51890028  1602590409              0        False
# 59  25259 -51890028 -51890028  1554800244              0        False
# 6     977 -51890028 -51890028  1416930109              0        False
# 47  75933 -51890028 -51890028  1604923204              0        False
# 38  42960 -51890028 -51890028  1568444249              0        False
# ..    ...       ...       ...         ...            ...          ...
# 71     66 -51890028 -51890028  1406198835              0        False
# 79   3190 -51890028 -51890028  1435133700              0        False
# 17   7497 -51890028 -51890028  1472465104              0        False
# 32   7452 -51890028 -51890028  1472033119              0        False
# 23   7489 -51890028 -51890028  1472205905              0        False
#
#    post_type                                               text  \
# 12      post  КОНКУРС! Выиграйте уроки английского и бьюти-б...
# 59      post  Через 15 дней вы накачаете пресс и выучите анг...
# 6       post  100 полезных английских фраз\nЭти фразы выруча...
# 47      post  КОНКУРС! Выиграйте уроки английского и боксы с...
# 38      post  😑Предлоги в английском — больная тема для всех...
# ..       ...                                                ...
# 71      post  А вам достаточно 3-х часов в неделю? Или нужно...
# 79      post  Hotel Echo Lima Lima Oscar!\nhttp://skyeng.ru/...
# 17      post  Новый 4G-смартфон SENSEIT A109 порадует не тол...
# 32      post  Покупайте новый 4G-смартфон SENSEIT A109 и пол...
# 23      post  Выбираете новый смартфон? 4G-смартфон SENSEIT ...
#
#                                           attachments     post_source  ...  \
# 12  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 59  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 6   [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 47  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 38  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# ..                                                ...             ...  ...
# 71                                                NaN  {'type': 'vk'}  ...
# 79  [{'type': 'link', 'link': {'url': 'http://skye...  {'type': 'vk'}  ...
# 17  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 32  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 23  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
#
#    carousel_offset        edited  \
# 12             0.0           NaN
# 59             0.0  1.554800e+09
# 6              0.0  1.416991e+09
# 47             0.0           NaN
# 38             0.0  1.568449e+09
# ..             ...           ...
# 71             NaN           NaN
# 79             NaN           NaN
# 17             0.0           NaN
# 32             0.0           NaN
# 23             0.0           NaN
#
#                                          copy_history signer_id zoom_text  \
# 12                                                NaN       NaN       NaN
# 59                                                NaN       NaN       NaN
# 6                                                 NaN       NaN       NaN
# 47                                                NaN       NaN       NaN
# 38                                                NaN       NaN       NaN
# ..                                                ...       ...       ...
# 71  [{'id': 65699, 'owner_id': -24098496, 'is_dele...       NaN       NaN
# 79                                                NaN       NaN       NaN
# 17                                                NaN       NaN       NaN
# 32                                                NaN       NaN       NaN
# 23                                                NaN       NaN       NaN
#
#     geo comments_count  likes_count  reposts_count activity
# 12  NaN          10962          117              2    11081
# 59  NaN            239         6998           1391     8628
# 6   NaN              0         4012            974     4986
# 47  NaN           2891          133              6     3030
# 38  NaN             50         1923            440     2413
# ..  ...            ...          ...            ...      ...
# 71  NaN              0            0              0        0
# 79  NaN              0            0              0        0
# 17  NaN              0            0              0        0
# 32  NaN              0            0              0        0
# 23  NaN              0            0              0        0
#
# [8013 rows x 27 columns]

# %% [markdown]
# ## Задание 5
#
# __Почисти данные, сохрани результат в файл для отправки копирайтерам__
#
# 1. Отфильтруй в датафрейме только нужные столбцы:
#     - дата поста
#     - текст поста
#     - количество комментариев
#     - количество лайков
#     - количество репостов
#     - общее количество пользовательских активностей
#
# 2. Выгрузи датафрейм в .csv файл

# %%
import time
posts['date'] = pd.to_datetime(posts['date'])

# %%
# напиши здесь код

sending_posts = posts[['date', 'text', 'comments_count', 'likes_count', 'reposts_count', 'activity']]
sending_posts
sending_posts.to_excel('populary_posts.xlsx')

# %% [markdown]
# ## EXTRA
#
# __К 50 самым популярным постам выгрузи все комментарии, чтобы оценить, как пользователи восприняли посты__
#
# 1. Создай цикл, который проходит по всем `post ID`
# 2. В каждом цикле собери все комментарии к посту, используя `offset`
# 3. В каждом цикле достань лайки в отдельный столбец
# 4. Собери все комментарии в одном датафрейме
#
#
#
# *Обрати внимание, что для работы с постами нужны __дополнительные параметры в токене__*

# %% [markdown]
# # 🎉🎉🎉 Поздравляем, ты великолепен!
